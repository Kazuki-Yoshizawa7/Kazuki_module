# %% [markdown]
# # このNotebookでは、MultiprocessingやAsyncなどの方法で効率化する方法を試す：
# ### まず、SemanticSegmentation用のLabel,Predを読み込み、すべてのDifferenceやRatioを計算するための枠組みを作ってみる

# %% [markdown]
# # load file & DataFrame Creation

# %%
import multiprocessing
