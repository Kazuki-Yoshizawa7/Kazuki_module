# %%
import pandas as pd
import yfinance as yf 
import numpy as np 
import matplotlib.pyplot as plt
import datetime
import seaborn as sns 
from kazustat import YFinanceAnalysis
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# 9201 JAL 
# 9202 ANA

# %%
analyzer = YFinanceAnalysis(codes=['9201.T','9202.T'], start='2020-01-01', end='2025-12-30')
analyzer.describe_codes()
# Out:
# Plotting for 9201.T
# [*********************100%***********************]  1 of 1 completed
# Plotting for 9202.T
# [*********************100%***********************]  1 of 1 completed

# %%
analyzer.scatter_show()
